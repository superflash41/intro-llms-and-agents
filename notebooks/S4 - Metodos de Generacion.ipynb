# %% [markdown]
# # Instalar dependencias

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %cd  /content/drive/MyDrive/nlp-applications-class/semana2/
# Out:
# /content/drive/MyDrive/nlp-applications-class/semana2

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.1/314.1 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...

# %% [markdown]
# # Usando modelos pre-entrenados de HuggingFace
# En esta section vamos a probar modelos disponibles en [HuggingFace](https://https://huggingface.co/), un repositorio masivo de modelos y datasets para diversas aplicaciones de NLP, Vision, Audio, entre otros.
#
# Como libreria backbone emplearemos Transformers, que a su vez extiende pytorch.

# %% [markdown]
# ## Pipeline para usar un modelo por defecto
# GPT2 - 124M parametros

# %%
from transformers import pipeline, set_seed

generator = pipeline('text-generation', model='gpt2')

set_seed(42)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %% [markdown]
# Greedy Search (Busqueda Avara)

# %%
output = generator("Hello, I'm a language model,", max_length=30, num_return_sequences=1, do_sample=False)
print(output['generated_text'])
# print(output)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, not a programming language. I'm a language model. I'm a language model. I'm a language model"}]

# %% [markdown]
# Beam Search

# %%
generator("Hello, I'm a language model, and", max_length=50, num_return_sequences=10)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, and there's no reason why you should try to mimic them with a more refined and precise understanding of your programming language when you create your database model.\n\nI hope that I've helped you here.\n"},
#  {'generated_text': "Hello, I'm a language model, and I've been in over 600 languages I've understood. Now I'm just not sure how it's going to go. I think I will have to try new things to get it right.\n\nThe"},
#  {'generated_text': "Hello, I'm a language model, and you're a philosopher? So, you know, if I was to talk to every teacher who taught at UC Berkeley, and every teacher who taught at UC Berkeley, they would stop me. Why is that"},
# ...

# %% [markdown]
# ## Sampling (Muestreo)

# %% [markdown]
# Ancestral Sampling (Muestreo de Ancestros)

# %%
generator("Hello, I'm a language model,", max_length=40, num_return_sequences=1, do_sample=True, temperature=1.0)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, a language model; we use an entire library of languages to model languages. We want to be able to communicate to each other, and we wanted to have languages"}]

# %%
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=1, do_sample=True, temperature=0.1)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, not a programming language. I'm a language model. I'm a programming language. I'm a programming language"}]

# %%
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=1, do_sample=True, temperature=2.0)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Hello, I\'m a language model, just because you say "words should make languages understand" but there needs to be support of all our functions for'}]

# %% [markdown]
# Top-K Sampling

# %%
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=1, do_sample=True, top_k=1)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, not a programming language. I'm a language model. I'm a language model. I'm a language model"}]

# %%
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=1, do_sample=True, top_k=10)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, not a model of the universe. I am, in fact, a system-wide paradigm, a set of"}]

# %%
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=1, do_sample=True, top_k=1000)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, much better than you expect is what I just said.\n\nAL: How is the world for regular folk"}]

# %% [markdown]
# Nucleous Sampling (Muestreo de Nucleo)

# %%
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=1, do_sample=True, top_k=0, top_p=1.0)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, which means that your code in Rails can be implemented on top of JavaScript.\n\nHTTP Error Types\n\n"}]

# %%
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=1, do_sample=True, top_k=0, top_p=0.7)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, and I'll tell you the details.\n\nI'm writing a simple parser for the 4 fundamental levels."}]

# %%
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=1, do_sample=True, top_k=0, top_p=0.9, temperature=0.7)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Hello, I'm a language model, and I'm trying to help people understand the world. It's not a scientific term; it's a term"}]
